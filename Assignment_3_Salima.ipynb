# %%
import numpy as np
import pandas as pd
import statistics as stat

# %%
data_df = pd.read_csv('/content/StudentsPerformance.csv') #Uploaded file to session storage and save as data_df

# %%
data_df.head() # displying the 1st 5 rows of the data set
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %%
data_df.tail() # displayng the last 5 rows of the data set
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 995   male        group E                some college      standard
# 996   male        group A                some college      standard
# 997   male        group D                some college      standard
# 998   male        group E          associate's degree  free/reduced
# 999   male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 995               completed          99             87             81
# 996               completed         100             96             86
# 997               completed         100             97             99
# 998               completed         100            100             93
# 999               completed         100            100            100

# %%
data_df.info() # displying complete information about index, various columns,no. of null values, datatypes etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data_df.describe() #Function to find  various parameters like count, mean, standard deviation, min and max values.
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.001000      69.195000      68.119000
# std      15.569567      14.706436      15.226381
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.250000      79.000000
# max     100.000000     100.000000     100.000000

# %% [markdown]
# Q 1. Find out how many males and females participated in the test.

# %%
gender_counts = data_df['gender'].value_counts() #Counting males and females number separately
print("Number of males:", gender_counts['male']) # displaying or printing the number of males
print("Number of females:", gender_counts['female']) #displaying or printing the number of females
print('HAVE PARTICIPATED IN THE TEST') #PRINTING
# Out:
# Number of males: 482
# Number of females: 518
# HAVE PARTICIPATED IN THE TEST

# %% [markdown]
# Q 2. What do you think about the students' parental level of education?

# %%
parent_education = data_df['parental level of education'] # Extracting the required info and
                                                          #save it to another database i.e the parental level of education column

education_counts = parent_education.value_counts() # Counting the occurrences of each level of education

# Print the result
print("Parental Level of Education:") #Printing parental level of education as TITLE
print(education_counts) #Display the counted value
# Out:
# Parental Level of Education:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# Q 3.  Who scores the most on average for math, reading and writing based on

# %%
# Grouping by gender and test preparation course, and calculate the average scores
avg_scores = data_df.groupby(['gender', 'test preparation course']).mean()

# Printing the result
print("Average Scores:")
print(avg_scores)
# Out:
# Average Scores:
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                 67.108696      77.375000      78.793478
#        none                      61.320359      69.955090      68.982036
# male   completed                 72.988506      70.793103      70.339080
#        none                      66.467532      62.581169      59.551948
# <ipython-input-12-df4b0ac895f2>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_scores = data_df.groupby(['gender', 'test preparation course']).mean()

# %%
data_df.groupby('gender').mean() # Grouping by gender and calculate the average scores
# Out:
# <ipython-input-13-9f0bdaf2eaf4>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_df.groupby('gender').mean() # Grouping by gender and calculate the average scores
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
data_df.groupby('test preparation course').mean() # Grouping by test preparation course, and calculate the average scores
# Out:
# <ipython-input-14-bc4a2131e901>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_df.groupby('test preparation course').mean() # Grouping by test preparation course, and calculate the average scores
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %% [markdown]
# Q 4. What do you think about the scoring variation for math, reading and writing

# %%
# Calculate the standard deviation for math, reading, and writing scores based on gender and test preparation course
variation = data_df.groupby(['gender', 'test preparation course']).std()

# Print the result
print("Scoring Variation:")
print(variation)
# Out:
# Scoring Variation:
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                 14.428233      12.695493      12.240788
#        none                      16.510686      14.636981      15.016497
# male   completed                 14.039164      13.612420      12.887910
#        none                      14.335746      13.595718      13.468284
# <ipython-input-15-cf5cde3908e9>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   variation = data_df.groupby(['gender', 'test preparation course']).std()

# %%
data_df.groupby('gender').std() # Calculate the standard deviation for math, reading, and writing scores based on gender
# Out:
# <ipython-input-16-fc4c32f5425e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_df.groupby('gender').std() # Calculate the standard deviation for math, reading, and writing scores based on gender
#         math score  reading score  writing score
# gender
# female   16.029928      14.411018      14.844842
# male     14.556411      14.149594      14.227225

# %%
data_df.groupby('test preparation course').std() # Calculate the standard deviation for math, reading, and writing scores based on test preparation course
# Out:
# <ipython-input-17-ea59657ab08c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_df.groupby('test preparation course').std() # Calculate the standard deviation for math, reading, and writing scores based on test preparation course
#                          math score  reading score  writing score
# test preparation course
# completed                 14.521847      13.537572      13.236412
# none                      15.705689      14.608896      15.041667

# %% [markdown]
# the variance of the info given on the dataset

# %%
# Calculate the variance for math, reading, and writing scores based on gender and test preparation course
variance = data_df.groupby(['gender', 'test preparation course']).var()

# Print the result
print("Scoring Variation:")
print(variance)
# Out:
# Scoring Variation:
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                208.173913     161.175546     149.836897
#        none                     272.602767     214.241220     225.495172
# male   completed                197.098133     185.297987     166.098233
#        none                     205.513600     184.843553     181.394687
# <ipython-input-18-5233e3a35bc1>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.var is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   variance = data_df.groupby(['gender', 'test preparation course']).var()

# %%
data_df.groupby('gender').var() # Calculate the variance for math, reading, and writing scores based on gender
# Out:
# <ipython-input-19-c284f296e3ab>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.var is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_df.groupby('gender').var() # Calculate the variance for math, reading, and writing scores based on gender
#         math score  reading score  writing score
# gender
# female  256.958593     207.677438     220.369327
# male    211.889097     200.211010     202.413924

# %%
data_df.groupby('test preparation course').var() # Calculate the variance for math, reading, and writing scores based on test preparation course
# Out:
# <ipython-input-20-0916d4e03156>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.var is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_df.groupby('test preparation course').var() # Calculate the variance for math, reading, and writing scores based on test preparation course
#                          math score  reading score  writing score
# test preparation course
# completed                210.884027     183.265864     175.202612
# none                     246.668662     213.419851     226.251739

# %% [markdown]
# Q 5. The management needs your help to give bonus points to the top 25% of students based on their math score, so how will you help the management to achieve this.

# %%
# Calculate the score threshold for the top 25% of students based on math scores
math_threshold = data_df['math score'].quantile(0.75)

# Identify the top performers based on math scores
top_performers = data_df[data_df['math score'] >= math_threshold]

# Assign bonus points to the top performers
bonus_points = 10   # You can adjust the number of bonus points as needed
top_performers['bonus_points'] = bonus_points

# Display the top performers and their bonus points
print("Top Performers and Bonus Points:")
print(top_performers[['math score', 'bonus_points']])
# Out:
# Top Performers and Bonus Points:
#      math score  bonus_points
# 414          77            10
# 415          77            10
# 416          77            10
# 417          77            10
# 418          77            10
# ..          ...           ...
# 995          99            10
# 996         100            10
# 997         100            10
# 998         100            10
# 999         100            10
#
# [255 rows x 2 columns]
# <ipython-input-21-b34d9933cdc5>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_performers['bonus_points'] = bonus_points
